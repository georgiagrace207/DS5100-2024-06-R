# %%
# 5.1
import time
t0 = time.time()
my_list = []
for i in range(0, 99999):
    if i // 2 == 0:
        my_list.append(-i)
    my_list.append(i)

print('runtime: ', time.time() - t0)

# 5.2
t0 = time.time()
my_list = i * -1 if i // 2 == 1 else i for i in range (1, 100001)
print('runtime: ', time.time() - t0)


# 5.3
import numpy as np
my_list = np.random.randint(1, 7, 10)
print(', '.join(randos.astype(str)))

# 5.4

rand_int = np.random.randint(10)
print(type(rand_int))

rand_int2 = np.random.randint(1, 21, 5)
print(type(rand_int2))

# 5.5

from matplotlib.pyplot import hist
hist(rand_int2)

# 5.6
x = np.random.randn(2, 3)
print(x)

# 5.7
x * 2

# 5.8
x + x

# 5.9
1/x

#5.10

my_shape = (2, 4)
y = np.random.randn(2, 4)
z = np.random.randn(2, 4)

# 5.11

a = np.identity(4)

# 5.12

b = np.random.randn(5, 1)
b_slice = b()

# 5.13
b_slice[b_slice > 0.15]
