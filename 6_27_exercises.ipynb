# %%
class MyClass:
    """
    Example class for Exercise 7.1
    """

    att1 = "foo"

    def __init__(self, att2):
        self.att2 = att2

    def add(self):
        concatenate: (self.att1 + ' ' + self.att2)
    print(concatenate)


# 7.2

a = MyClass('test')
print(a.att1, a.att2)
print(a.add())


# 7.3

class Student:
    def __init__(self, name, user_id):
        self.name = name
        self.user_id = user_id
        self.grades = pd.Series(dtype = float)

    def add_grade(self, assignment, grade):
        self.grades.loc[assignment] = grade

    def show_grades(self):
        self.grades.plot.bar(title=f"Grades for {self.name} ({self.id})")


# 7.4

a = Student(Georgia, ggd8hvd)
a.add_grade(hw01, 97)
a.add_grade(hw02, 98)
a.add_grade(hw03, 99)
a.add_grade(hw04, 100)
a.show_grades()

# 7.4


class V3:
    def __init__(self, instance_size, num_vcpus, memory, disk_space):
        self.instance_size = instance_size
        self.num_vcpus = num_vcpus
        self.memory = memory
        self.disk_space = disk_space

    def add_disk_space(self, amt_to_add):
        self.disk_space += amt_to_add

    def has_enough_disk_space(self, amt_required):
        if self.disk_space >= amt_required:
            return True
        else:
            return False

# 7.5

b = V3('large', 32, 265, 1.)
b.add_disk_space(2.)
v.has_enough_disk_space(10.)

# 7.6

class Circle:
    def __init__(self, area, circumference):
        self.area = area
        self.circumference = circumference

    def area(self, pi, radius):
        pi = 3.14
        my_area = round(pi * (radius**2), 2)

    def circumference(self, pi, radius):
        pi = 3.14
        my_circumference = round(2 * (pi * radius), 2)
