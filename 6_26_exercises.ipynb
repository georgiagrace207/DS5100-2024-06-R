# %%
# 6.1

import pandas as pd
import numpy as np
import seaborn as sns

my_version = np.__version__
print(my_version)

pd_version = pd.__version__
print(pd_version)

df = pd.DataFrame({
    'features': [1.0, 2.0, 3.0],
    'labels': [1, 2, 3]
})

# 6.2

df = df.rename(columns={'labels': 'label'})

# 6.3

iris = sns.load_dataset('iris')
iris.sort_values(by=['species'], ascending = False)

# 6.4

my_count = iris.species.value_counts().to_frame('n')

# 6.5

record_count = iris.petal_length.value_counts()
for i in record_count:
    if i <= 1.4 or i >= 1.6:
        print(i)
print(len_)

# 6.6

iris['min_petal'] = iris.apply(lambda x: min(x.petal_length, x.petal_width), axis=1)
iris.head()

# 6.7

pd.pivot_table(iris, values=["sepal_width", "petal_width"], columns=["species"], aggfunc = [np.mean, np.median])

# 6.8

left = pd.DafaFrame({'key': ["jamie", "bill"], "lval": [15, 22]})
left = left.set_index('key')

# 6.9

data = pd. Series([1, 1, 2, 3, 5, 8])
np.reshape(data, (2, 3))

# 6.10

cats = pd.DataFrame({'breed':['persian', 'persian', 'siamese', 'himalayan', 'burmese'],
                     ['color']: ['calico', 'white', 'seal point', 'cream', 'sable']})

dummy = pd.get_dummies(cats, prefix=['b','c'])
